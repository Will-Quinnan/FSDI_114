# %%
#SinglyLinkedList implementation


class SinglyLinkedList:
    class Node:
        def __init__(self, data):
            self.data = data
            self.next = None
        
    def __init__(self):
        self.head = None
        self.tail = None
        self.length = 0
        
    def append(self, value):
        new_node = self.Node(value)
        if self.tail:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.length += 1
        if not self.head:
            self.head = new_node
            self.tail = new_node
            self.length += 1
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node
            new_node.prev = current
            self.length += 1
            
    def search(self, value):
        if not self.head:
            return False
        else:
            current = self.head
            tail = self.tail
            while current != tail:
                 if current.data != value and tail.data != value:
                        current = current.next
                        tail = tail.prev
                else:
                    return True
        return False
    
    #implement bianary search as a method to this class (DLL)

    def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:
                out += ", &s" % current.data
                current = current.next
        out+= "]"
        return out

# %%
# How python usually prints lists:
#Empty list:
print([])
#list with a single element:
print([1])
#Lists with multiple elements
print([1, 2, 3])
# Out:
# []
# [1]
# [1, 2, 3]

# %%
sll= SinglyLinkedList()

#empty list
print(sll)

#List with single elements
sll.append(1)
print(sll)

#list with multiple elements
for number in range(2, 4):
    sll.append(number)
    
print(sll)

# %%
mylist = [1, 2, 3]

mylist.insert(100, 100)

print(mylist)

# %%
#pseudocode implementation
# define function insert with parameters index and value:
#if the list is empty          //represented by the fact that head is set to None
    #then, simply update our node's "next" reference so it points to the head
    #and, update the head reference so it points to our node
#otherwise
    #// we need to validate that the index is within our list
    #// create a variable to keep track of how many times we've traversed
    # count = 0
    # my variable current is set to head node
    #create a reference to the previous node (called previous) which starts off as none
    # while count does not equal index and there is a next node to traverse into (current.next)
        # previous is updated to point to the same node as currtent
        #current is updated to the next node in sequence
        # add 1 to count
    #if previous was never updated, then , it means there was only 1 node in my list
        #append the newly created node in sequence
        #add 1 to count

# %%
class DoublyLinkedList:
    class Node: def __init__(self, data):
            delf.data = data
            self.next = None
            self.prev = None
    def __init__(self):
    
    
    def append(self, value):
        new_node = self.Node(value)
        if not self.head:
            delf.head = new_node
        else:
            current = self.head
            while current.next:
                current =current.next
            current.next = new_node
            new_node.prev = current
        
    def __str__(self):
            def __str__(self):
        out = "["
        if self.head:
            out += "%s" % self.head.data
            current = self.head.next
            while current:
                out += ", &s" % current.data
                current = current.next
        out+= "]"
        return out

# %%
dll = DoublyLinkedList()

print(dll)

dll.append(1)

print(dll)

dll.append(2)
dll.append(3)

# %% [markdown]
# # Challenge 1
#
# ### Given two integers as parrameters, create a box. The box must be comprised of "*".
#
# ####Example:
#
# ```
# myfunction(2, 2) should return:
#
# **
# **
#
# myfunction(3, 3) should return:
#
# ***
# * *
# ***
#
# myfunction(5, 5) should return:
# *****
# *   *
# *   *
# *   *
# *****
# ```
# Parameters will not always be the same
